# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
data = pd.read_csv('data - data.csv')
dataa = pd.read_csv('data - data.csv')

# %% [markdown]
# # Task 1

# %%
a = data['dateAdded'].head(3)
a.tolist()
# Out:
# ['2016-03-02T11:49:34Z', '2016-03-02T11:49:34Z', '2016-10-14T01:58:25Z']

# %% [markdown]
# # Task 2

# %%
data['city'].dtype
# Out:
# dtype('O')

# %%
data['latitude'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Task 3

# %%
data.describe()
# Out:
#            latitude     longitude
# count  31751.000000  31751.000000
# mean      36.729953    -99.103632
# std        4.813919     17.901536
# min        0.000000   -159.492690
# 25%       33.667449   -117.745199
# 50%       36.060012    -96.799095
# 75%       40.585903    -83.206091
# max       61.219460     30.167801

# %% [markdown]
# # Task 4

# %%
data.describe().mean()
# Out:
# latitude     3995.509587
# longitude    3905.340329
# dtype: float64

# %% [markdown]
# # Task 5

# %%
data = data.dropna()

# %% [markdown]
# # Task 6

# %%
result = data[data['city'] == 'California']
result
# Out:
# Empty DataFrame
# Columns: [id, address, categories, city, cuisines, dateAdded, dateUpdated, latitude, longitude, menus.category, menus.currency, menus.dateSeen, menus.description, menus.name, name, province]
# Index: []

# %% [markdown]
# # Task 7

# %%
result = data[(data['city'] == 'California') & (data['name'] == 'Taco Bell')]
result
# Out:
# Empty DataFrame
# Columns: [id, address, categories, city, cuisines, dateAdded, dateUpdated, latitude, longitude, menus.category, menus.currency, menus.dateSeen, menus.description, menus.name, name, province]
# Index: []

# %% [markdown]
# # Task 8

# %%
data2 = data.dropna()
result = data2[((data2['city'] == 'New York') | (data2['name'] == 'Taco Bell')) & ~((data2['menus.name'] == 'Volcano Taco') | (data2['menus.name'] == 'Fresco Soft Taco'))]
result
# Out:
#                          id                        address  \
# 1995   AVwc15AmByjofQCxix8i                   44 W 44th St
# 2862   AVwc23sokufWRAb5zvzm                 713 Second Ave
# 2876   AVwc24rw_7pvs4fzzsiR                    785 9th Ave
# 6884   AVwc6MLH_7pvs4fz0Qj-                  505 Third Ave
# 8000   AVwc7NwAkufWRAb50fDa                  622 Tenth Ave
# 9233   AVwc9D6LkufWRAb50xpO                  119 E 18th St
# 11859  AVwcgbYk_7pvs4fzv0bV   475 W Broadway At Houston St
# 11860  AVwcgbYk_7pvs4fzv0bV   475 W Broadway At Houston St
# 11862  AVwcgbYk_7pvs4fzv0bV   475 W Broadway At Houston St
# 11863  AVwcgbYk_7pvs4fzv0bV   475 W Broadway At Houston St
# 15244  AVwcisC3_7pvs4fzwPl9                  160 E 38th St
# 15245  AVwcisC3_7pvs4fzwPl9                  160 E 38th St
# 15246  AVwcisC3_7pvs4fzwPl9                  160 E 38th St
# 15248  AVwcisC3_7pvs4fzwPl9                  160 E 38th St
# 15249  AVwcisC3_7pvs4fzwPl9                  160 E 38th St
# ...

# %% [markdown]
# # Task 9

# %%
curr_no = data[data['menus.currency'].notna()]
curr_no
# Out:
#                          id                                         address  \
# 72     AVwc_6st_7pvs4fz1Mln                                  95 Matthews Dr
# 242    AVwc_DjlkufWRAb51GPc                              2610 Lyndale Ave S
# 243    AVwc_DjlkufWRAb51GPc                              2610 Lyndale Ave S
# 259    AVwc_DW1_7pvs4fz1DBV                                   119 W Clay St
# 261    AVwc_DW1_7pvs4fz1DBV                                   119 W Clay St
# 330    AVwc_-hF_7pvs4fz1NQH                            10670 Boardwalk Loop
# 331    AVwc_-hF_7pvs4fz1NQH                            10670 Boardwalk Loop
# 338    AVwc_htWByjofQCxkYch                               1201 Strassner Dr
# 509    AVwc_O7E_7pvs4fz1E8f                                100 Westgate Cir
# 612    AVwc_QWrIN2L1WUfrC52                                212 B Merrick Rd
# 640    AVwc_TgbIN2L1WUfrDdr                             1100 El Camino Real
# ...

# %% [markdown]
# # Task 10

# %%
data['categories'].dtype
# Out:
# dtype('O')

# %%
data[['categories']]
# Out:
#                                                                                                                                                                                                                                        categories
# 72                                                                                                                                                                                                                                     Restaurant
# 242                                                                                                                                                                                                                                    Restaurant
# 243                                                                                                                                                                                                                                    Restaurant
# ...

# %% [markdown]
# # Task 11

# %%
a = data['city'].value_counts()
a = a.nlargest(5)
a
# Out:
# city
# Los Angeles    71
# San Diego      41
# New York       32
# Las Vegas      26
# Chicago        22
# Name: count, dtype: int64

# %% [markdown]
# # Task 12

# %%
taco_bell = dataa[dataa['name'] == 'Taco Bell']
taco_bell_city = taco_bell['city'].value_counts()
result = taco_bell_city.head(5)
result
# Out:
# city
# Indianapolis    84
# Columbus        63
# Yukon           42
# Albuquerque     42
# Fresno          42
# Name: count, dtype: int64

# %% [markdown]
# # Task 13

# %%
open_oct = dataa[dataa['dateAdded'].str[5:7] == '10']

# %%
open_oct_id = open_oct.index[:5]
open_oct_id_sort = sorted(open_oct_id)
result = ','.join(map(str, open_oct_id))
result
# Out:
# '2,21,22,23,24'

# %% [markdown]
# # Task 14

# %%
data['dateAdded'] = pd.to_datetime(data['dateAdded'])
data['a'] = data['dateAdded'].dt.to_period('M')
result = data.groupby('a')['id'].nunique()
result
# Out:
# /tmp/ipython-input-20-3994034447.py:2: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   data['a'] = data['dateAdded'].dt.to_period('M')
# a
# 2014-01     4
# 2014-02     3
# 2015-01     1
# 2015-06     1
# 2015-07     1
# 2015-09     6
# 2015-10    86
# 2015-11    17
# 2015-12     2
# 2016-02     1
# 2016-03    37
# 2016-04    41
# 2016-05    21
# 2016-06    13
# 2016-07    61
# 2016-08    99
# 2016-10     4
# 2016-11     2
# 2017-01     5
# 2017-02     6
# 2017-03     6
# 2017-04     6
# Freq: M, Name: id, dtype: int64

# %% [markdown]
# # Task 15

# %%
data['dateAdded'] = pd.to_datetime(data['dateAdded'])
data['dateUpdated'] = pd.to_datetime(data['dateUpdated'])
data['update_delta'] = (data['dateUpdated'] - data['dateAdded']).dt.days
data['update_delta']
# Out:
# 72        307
# 242        20
# 243        20
# 259       459
# 261       459
# 330        14
# 331        14
# 338       117
# 509        89
# 612       294
# 640         6
# 715       489
# 727       414
# 728       414
# 738         0
# 818       137
# 1411        0
# 1412        0
# 1469       24
# 1690       18
# 1691       18
# 1692       18
# 1693       18
# 1797       18
# 1803      262
# 1849      415
# 1850      415
# 1851      415
# 1852      415
# 1853      415
# 1854      415
# 1855      415
# 1856      415
# 1857      415
# 1858      415
# 1859      415
# 1860      415
# 1959        0
# 1960        0
# 1961        0
# 1962        0
# 1963        0
# 1964        0
# 1965        0
# 1966        0
# 1967        0
# 1968        0
# 1995       23
# 2075      122
# 2152      462
# 2388      350
# 2394      350
# 2466      479
# 2467      479
# 2468      479
# 2469      479
# 2479      256
# 2481      563
# 2482      563
# 2483      563
# 2484      563
# 2638      350
# ...

# %%
data['update_delta'].mean()
# Out:
# np.float64(200.40145228215766)

# %%
a = data.loc[data['latitude'] == data['latitude'].max()]
result = a[['name', 'city', 'latitude']]
mean = data[data['city'] == 'Zephyrhills']['update_delta'].mean()
result
# Out:
#                 name        city   latitude
# 27693  The Black Cat  Bellingham  48.719996
# 27694  The Black Cat  Bellingham  48.719996

# %% [markdown]
# # Task 16

# %%
result = dataa[dataa['categories'].str.contains('Pizza', case = False, na = False)]
result.index[2]
# Out:
# np.int64(66)

# %% [markdown]
# # Task 17

# %%
data['update_delta'].mean()
# Out:
# np.float64(200.40145228215766)

# %%
data['update_delta'].median()
# Out:
# 80.0

# %% [markdown]
# # Task 18

# %%
data_filt = dataa[dataa['menus.description'].str.len() > 20]
result = data_filt.groupby('city')['longitude'].mean().reset_index()
result['longitude'] = result['longitude'].round(3)
result.to_csv('result.csv', sep=';', index=False)
